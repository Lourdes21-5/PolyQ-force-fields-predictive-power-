# %% [markdown]
# # SASA Analysis - Lourdes

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
import seaborn as sns
import pandas as pd
import mdtraj as md
import scipy.stats as st
import nglview as nv
import MDAnalysis as mda
from nglview.datafiles import PDB,XTC
from scipy.spatial.distance import cdist
# %matplotlib inline
import os
import matplotlib.pyplot as plt
from matplotlib import cm
#from scipy.stats import gaussian_kde
from Bio.SeqUtils import IUPACData
from __future__ import print_function
import scipy.cluster.hierarchy
from scipy.spatial.distance import squareform
import itertools
import mdtraj.testing
from itertools import product
import statistics
from statistics import mean, median, mode, stdev

# %%
def read_trajectory (dirname, equil=0, temp=1):
    topname = os.path.join(dirname, 'prot.pdb')
    trajname = os.path.join(dirname, f'prod{temp}_prot.xtc')
    t = md.load(trajname, top=topname, stride=1)
    t = t[equil:]
    t.remove_solvent(inplace=True)
    return t

def helicity (t):
    ss = md.compute_dssp(t,simplified=True)
    ssh = (ss=='H').astype(np.float)
    ssc = (ss=='C').astype(np.float)
    t_helix = t[np.all(ssh[:,6:10]>0,1)]
    return t_helix

def distance_hbond (t):
    #Calculate the distance between the Q1 (sc) and L1 (mc)
    #These are the potential donor atom names.
    #Selecting the hydrogens of Q1
    donors_helix = t.topology.select('residue 11 and name HE1 HE2 HE21 HE22')
    if donors_helix.size==0: 
        np.array([9999.])
    #Selecting the oxigen of L1
    acceptor_helix = t.topology.select('residue 7 and name O')
    pairs_helix = list(product(donors_helix, acceptor_helix))
    d_helix = md.compute_distances(t, pairs_helix)
    #We take the shortest distance
    d_helix = d_helix.min(1)
    d_helix *= 10 #to angstroms
    return d_helix

def distance_O (t):
    mcO = t.topology.select('residue 7 and name O')
    scO = t.topology.select('residue 11 and name O')
    pairO = list(product(mcO,scO))
    d_O = md.compute_distances(t,pairO)
    d_O *= 10
    return d_O

def freq_hbond (t):
    #Calculate the distance between the Q1 (sc) and L1 (mc)
    #These are the potential donor atom names.
    #Selecting the hydrogens of Q1
    donors_helix = t.topology.select('residue 11 and name HE1 HE2 HE21 HE22')
    if donors_helix.size==0: 
        np.array([9999.])
    #Selecting the oxigen of L1
    acceptor_helix = t.topology.select('residue 7 and name O')
    pairs_helix = list(product(donors_helix, acceptor_helix))
    try:
        d_helix = md.compute_distances(t, pairs_helix)
        #We take the shortest distance
        d_helix = d_helix.min(1)
        d_helix *= 10 #to angstroms
        t_hhbond = t[d_helix<2.4]
        frequency_hbond = len(t_hhbond)/len(t)
    except:
        frequency_hbond = 0
    return frequency_hbond

def select_index (t):
    try:
        Q1sc_index = t.topology.select('residue 11 and name HE21 HE2')
        Q1mc_index = t.topology.select('residue 11 and name H')
        L1_index = t.topology.select('residue 7 and name O')
        return Q1sc_index, Q1mc_index, L1_index
    except:
        pass
    
def calculate_sasa (t, Q1sc_index, Q1mc_index, L1_index):
    sasa = md.shrake_rupley(t, mode='atom')
    # sc Hydrogen Q1/E1 sasa
    if Q1sc_index.size > 0:
        Q1sc = sasa[:,Q1sc_index]
        Q1sc = mean (Q1sc[:,0])
    else:
        Q1sc = 0
    # mc Hydrogen Q1/E1 sasa
    Q1mc = sasa[:,Q1mc_index]
    Q1mc = mean (Q1mc[:,0])
    # mc Oxigen L1 sasa
    L1 = sasa[:,L1_index]
    L1 = mean (L1[:,0])
    return Q1sc, Q1mc, L1

def sasa_frames (t, Q1sc_index, Q1mc_index, L1_index):
    sasa_F = md.shrake_rupley(t, mode='atom')
    if Q1sc_index.size > 0:
        Q1Hsc = sasa_F[:,Q1sc_index]
    else:
        Q1Hsc = np.array[0,0]
    Q1Hmc = sasa_F[:,Q1mc_index]
    L1O = sasa_F[:,L1_index]
    return Q1Hsc, Q1Hmc, L1O

# %%
path = f'/home/lourdes/TFM-LOURDES/data/ALL/L4_Q12_DES-amber'
t = read_trajectory(path, equil=0)
t = helicity(t)
distance = distance_hbond(t[:])
d_O = distance_O(t)
print(len(distance))
print(len(d_O))
Q1sc_index,Q1mc_index,L1_index = select_index(t)
#print (Q1sc_index,Q1mc_index,L1_index)
Q1Hsc, Q1Hmc, L1O = sasa_frames(t, Q1sc_index, Q1mc_index, L1_index)
#print (Q1Hsc, Q1Hmc, L1O )
# Out:
# 11439
# 11439

# %%
#print (Q1Hsc, Q1Hmc, L1O )
print (mean(Q1Hsc[:,0]),mean(Q1Hmc[:,0]),mean(L1O[:,0]))
# Out:
# 0.13559142 0.00011667961 0.013247123

# %%
fig = plt.figure(figsize=(10,9))
sns.set_style('whitegrid')
plt.suptitle('L4_Q12_DES-amber', fontsize=22)

plt.subplot(411)
plt.scatter(Q1Hsc[:,0], Q1Hmc[:,0],label='H1 SASA mc - Q1', color='red')
plt.xlabel('SASA sc He21 - Q1')
plt.ylabel('SASA mc H - Q1')
#plt.xlim(0.0,0.30)
#plt.ylim(0,0.002)
plt.legend()

plt.subplot(412)
plt.scatter(Q1Hsc[:,0], L1O[:,0], label='O SASA mc - L1', color='black')
plt.xlabel('SASA sc He21 - Q1')
plt.ylabel('SASA mc O - L1')
#plt.xlim(0.0,0.30)
#plt.ylim(0,0.1)
plt.legend()

plt.subplot(413)
plt.scatter(Q1Hsc[:,0], distance, label='He21 SASA sc - Q1', color='green')
plt.xlabel('SASA sc He21 - Q1')
plt.ylabel('sc(i)-mc(i-4) hbond distance')
#plt.xlim(0.0,0.30)
#plt.ylim(1.5,3.0)
plt.legend()

plt.subplot(414)
plt.scatter(Q1Hsc[:,0],d_O,label=)

fig.tight_layout()

# %%
data = f'/home/lourdes/TFM-LOURDES/data/ALL/L4_Q12_DES-amber/area.xvg'
He21sc, Hmc, Omc = [], [], []

with open(data) as f:
    for line in f:
        cols = line.split()
        Hmc.append(float(cols[2])) #H mc 
        He21sc.append(float(cols[3])) #He21 sc
        Omc.append(float(cols[4])) #O mc



print(mean(He21sc))
print (mean(Hmc))
print(mean(Omc))
# Out:
# 0.14334973251337432
# 0.013855257237138143
# 0.06461886905654718

# %%
fig = plt.figure(figsize=(10,9))
plt.suptitle("L4_Q12_DES-amber")  

plt.subplot(311)
plt.scatter(He21sc,Hmc, c='r', label='H mc - Q1')
plt.xlabel('SASA He21sc - Q1')
plt.ylabel('SASA H - Q1')
plt.legend()


plt.subplot(312)
plt.scatter(He21sc,Omc, c='k', label='O mc - L1')
plt.xlabel('SASA He21sc - Q1')
plt.ylabel('SASA O - L1')
plt.legend()

plt.subplot(313)
plt.scatter(He21sc, distance, c='green', label='sc-mc distance')
plt.xlabel('SASA He21sc')
plt.ylabel('sc-mc hydrogen bond distance')
plt.legend()


fig.tight_layout()

# %%
fig = plt.figure(figsize=(10,9))
plt.subplot(311)
plt.scatter(Q1Hmc, distance, label='He21 SASA sc - Q1', color='green')
plt.xlabel('SASA sc He21 - Q1')
plt.ylabel('sc(i)-mc(i-4) hbond distance')
#plt.xlim(0.0,0.30)
#plt.ylim(0.0,15.0)
plt.legend()

plt.subplot(312)
plt.scatter(L1O, distance, label='He21 SASA sc - Q1', color='green')
plt.xlabel('SASA sc He21 - Q1')
plt.ylabel('sc(i)-mc(i-4) hbond distance')
#plt.xlim(0.0,0.30)
#plt.ylim(0.0,15.0)
plt.legend()

# %%
system_list = ('L4_Q12_DES-amber','A4_Q12_DES-amber','Q1EH_DES-amber','Q1E_DES-amber')
t={}
t_helix={}
Q1sc_index={}
Q1mc_index={}
L1_index={}
frequency_hbond={}
Q1sc={}
Q1mc={}
L1={}

for system in system_list: 
    path = f'/home/lourdes/TFM-LOURDES/data/ALL/{system}'
    t[system] = read_trajectory(path, equil=7000)
    t_helix[system] = helicity(t[system])
    frequency_hbond[system] = freq_hbond(t_helix[system])
    print (system, len(t[system]), len(t_helix[system]), frequency_hbond[system])
    Q1sc_index[system],Q1mc_index[system],L1_index[system] = select_index(t_helix[system])
    print (system, Q1sc_index[system],Q1mc_index[system],L1_index[system])
    Q1sc[system],Q1mc[system],L1[system] = calculate_sasa(t_helix[system],Q1sc_index[system], Q1mc_index[system], L1_index[system])
    print (system,Q1sc[system],Q1mc[system],L1[system])
# Out:
# L4_Q12_DES-amber 13001 9106 0.04908851306830661
# L4_Q12_DES-amber [177] [165] [106]
# L4_Q12_DES-amber 0.1379256 0.00010455639 0.014273366
# A4_Q12_DES-amber 13001 4237 0.015341043190936984
# A4_Q12_DES-amber [141] [129] [97]
# A4_Q12_DES-amber 0.15875638 0.00012500072 0.02263969
# Q1EH_DES-amber 13001 10454 0.016548689496843315
# Q1EH_DES-amber [177] [165] [106]
# Q1EH_DES-amber 0.13857932 6.845397e-05 0.009120708
# Q1E_DES-amber 11877 5174 0
# Q1E_DES-amber [] [165] [106]
# Q1E_DES-amber 0 0.00021979022 0.019491153

# %%
print (frequency_hbond)
print (Q1sc)
print (Q1mc)
print (L1)
# Out:
# {'L4_Q12_DES-amber': 0.04908851306830661, 'A4_Q12_DES-amber': 0.015341043190936984, 'Q1EH_DES-amber': 0.016548689496843315, 'Q1E_DES-amber': 0}
# {'L4_Q12_DES-amber': 0.1379256, 'A4_Q12_DES-amber': 0.15875638, 'Q1EH_DES-amber': 0.13857932, 'Q1E_DES-amber': 0}
# {'L4_Q12_DES-amber': 0.00010455639, 'A4_Q12_DES-amber': 0.00012500072, 'Q1EH_DES-amber': 6.845397e-05, 'Q1E_DES-amber': 0.00021979022}
# {'L4_Q12_DES-amber': 0.014273366, 'A4_Q12_DES-amber': 0.02263969, 'Q1EH_DES-amber': 0.009120708, 'Q1E_DES-amber': 0.019491153}

# %%
fig = plt.figure(figsize=(10,9))
sns.set_style('whitegrid')
plt.suptitle('SASA correlation with sc-mc hbond frequency', fontsize=22)

plt.subplot(311)
plt.scatter(Q1sc['L4_Q12_DES-amber'], frequency_hbond['L4_Q12_DES-amber'], label='L4_Q12_DES-amber', color='green')
plt.scatter(Q1sc['A4_Q12_DES-amber'], frequency_hbond['A4_Q12_DES-amber'], label='A4_Q12_DES-amber', color='red')
plt.scatter(Q1sc['Q1EH_DES-amber'], frequency_hbond['Q1EH_DES-amber'], label='Q1EH_DES-amber', color='black')
plt.scatter(Q1sc['Q1E_DES-amber'], frequency_hbond['Q1E_DES-amber'], label='Q1E_DES-amber', color='blue')
plt.ylabel('frequency sc-mc Hbond', size=11)
plt.xlabel('Total HE21 SASA (nm)^2', size=12)
plt.xlim(0.0,0.20)
plt.ylim(0,0.1)
plt.legend()

plt.subplot(312)
plt.scatter(Q1mc['L4_Q12_DES-amber'], frequency_hbond['L4_Q12_DES-amber'], label='L4_Q12_DES-amber', color='green')
plt.scatter(Q1mc['A4_Q12_DES-amber'], frequency_hbond['A4_Q12_DES-amber'], label='A4_Q12_DES-amber', color='red')
plt.scatter(Q1mc['Q1EH_DES-amber'], frequency_hbond['Q1EH_DES-amber'], label='Q1EH_DES-amber', color='black')
plt.scatter(Q1mc['Q1E_DES-amber'], frequency_hbond['Q1E_DES-amber'], label='Q1E_DES-amber', color='blue')
plt.ylabel('frequency sc-mc Hbond', size=11)
plt.xlabel('Total H SASA (nm)^2', size=12)
plt.xlim(0.0,0.00025)
plt.ylim(0,0.1)
plt.legend()

plt.subplot(313)
plt.scatter(L1['L4_Q12_DES-amber'], frequency_hbond['L4_Q12_DES-amber'], label='L4_Q12_DES-amber', color='green')
plt.scatter(L1['A4_Q12_DES-amber'], frequency_hbond['A4_Q12_DES-amber'], label='A4_Q12_DES-amber', color='red')
plt.scatter(L1['Q1EH_DES-amber'], frequency_hbond['Q1EH_DES-amber'], label='Q1EH_DES-amber', color='black')
plt.scatter(L1['Q1E_DES-amber'], frequency_hbond['Q1E_DES-amber'], label='Q1E_DES-amber', color='blue')
plt.ylabel('frequency sc-mc Hbond', size=11)
plt.xlabel('Total O SASA (nm)^2', size=12)
plt.xlim(0.0,0.050)
plt.ylim(0,0.1)
plt.legend()



fig.tight_layout()
